# %% [markdown]
# Este projeto também está incompleto.

# %%
import pandas as pd
import geopandas as gpd

url_obesidade = 'https://en.wikipedia.org/wiki/List_of_countries_by_obesity_rate'
tabelas_obesidade = pd.read_html(url_obesidade)
dados_obesidade = tabelas_obesidade[0]

url_pib = 'https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)_per_capita'
tabelas_pib = pd.read_html(url_pib)
dados_pib = tabelas_pib[1]

display(dados_pib)
#display(dados_obesidade)
# Out:
#     Country/Territory UN Region IMF[4][5]       World Bank[6]        \
#     Country/Territory UN Region  Estimate  Year      Estimate  Year
# 0                 NaN       NaN       NaN   NaN           NaN   NaN
# 1              Monaco    Europe         —     —        234316  2021
# 2       Liechtenstein    Europe         —     —        157755  2020
# 3          Luxembourg    Europe    132372  2023        133590  2021
# 4             Ireland    Europe    114581  2023        100172  2021
# ..                ...       ...       ...   ...           ...   ...
# 219            Malawi    Africa       496  2023           635  2021
# 220       South Sudan    Africa       467  2023          1072  2015
# 221      Sierra Leone    Africa       415  2023           480  2021
# 222       Afghanistan      Asia       611  2020           369  2021
# 223           Burundi    Africa       249  2023           222  2021
#
#     United Nations[7]
#              Estimate  Year
# 0                 NaN   NaN
# 1              234317  2021
# 2              169260  2021
# 3              133745  2021
# 4              101109  2021
# ..                ...   ...
# 219               613  2021
# 220               400  2021
# 221               505  2021
# 222               373  2021
# 223               311  2021
#
# [224 rows x 8 columns]

# %% [markdown]
# from fuzzywuzzy import fuzz
#
# pd.set_option('display.max_rows', None)  # Mostrar todas as linhas
#
# pib_teste = dados_pib.copy()
# obsd_teste = dados_obesidade.copy()
#
# #linhas_extras_pib = pib_teste['Country/Territory'][pib_teste['Country/Territory'].isin(obsd_teste['Country'])]
# #linhas_extras_obsd = obsd_teste['Country'][~obsd_teste['Country'].isin(pib_teste['Country/Territory'])]
#
# display(linhas_extras_pib)

# %%
dados_cruzados = pd.merge(dados_pib, dados_obesidade, left_on=('Country/Territory','Country/Territory'), right_on='Country')

#dados.dropna(axis=0, inplace=True, subset='Obesity rate (%)')

print(dados_cruzados)
# Out:
# C:\Users\jojos\AppData\Local\Temp\ipykernel_15272\3839125016.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left, 2 on the right)
#   dados_cruzados = dados_obesidade.merge(dados_pib, how='left', left_on='Country', right_on='Country/Territory')
# ------------------------------------------------------------------------
# ValueError                             Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dados_cruzados = dados_obesidade.merge(dados_pib, how='left', left_on='Country', right_on='Country/Territory')
#       3 #dados.dropna(axis=0, inplace=True, subset='Obesity rate (%)')
#       5 print(dados_cruzados)
#
# File ~\.conda\envs\geo_env\Lib\site-packages\pandas\core\frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
#   10101         right_index=right_index,
#   10102         sort=sort,
#   10103         suffixes=suffixes,
#   10104         copy=copy,
#   10105         indicator=indicator,
#   10106         validate=validate,
#   10107     )
#
# File ~\.conda\envs\geo_env\Lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File ~\.conda\envs\geo_env\Lib\site-packages\pandas\core\reshape\merge.py:703, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     696 self._cross = cross_col
#     698 # note this function has side effects
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
# --> 703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
#     707 self._maybe_coerce_merge_keys()
#
# File ~\.conda\envs\geo_env\Lib\site-packages\pandas\core\reshape\merge.py:1162, in _MergeOperation._get_merge_keys(self)
#    1160 rk = cast(Hashable, rk)
#    1161 if rk is not None:
# -> 1162     right_keys.append(right._get_label_or_level_values(rk))
#    1163 else:
#    1164     # work-around for merge_asof(right_index=True)
#    1165     right_keys.append(right.index)
#
# File ~\.conda\envs\geo_env\Lib\site-packages\pandas\core\generic.py:1865, in NDFrame._get_label_or_level_values(self, key, axis)
#    1862         multi_message = ""
#    1864     label_axis_name = "column" if axis == 0 else "index"
# -> 1865     raise ValueError(
#    1866         f"The {label_axis_name} label '{key}' is not unique.{multi_message}"
#    1867     )
#    1869 return values
#
# ValueError: The column label 'Country/Territory' is not unique.
# For a multi-index, the label must be a tuple with elements corresponding to each level.
