# %% [markdown]
# Como utilizar o bikepath_maker:

# %% [markdown]
# Comece com duas tabelas contendo os polígonos relevantes para a análise,
# normalmente, usamos zonas censitárias e buffers relativos a pontos de interesse diversos.

# %% [markdown]
# Execute cada célula e veja seu resultado, altere conforme o desejado.

# %% [markdown]
# Parte 1 - Imports:

# %%
import geopandas as gpd
import pandas as pd
import folium
import json
from shapely.geometry import LineString
import modules.pather as path
import modules.sorter as sort
from shapely import Point
import ipywidgets as widgets
from IPython.display import display
from time import sleep
import pyproj
import requests

# %% [markdown]
# Parte 2 - Criação do mapa e das zonas censitárias (polígonos) [a mensagem de aviso abaixo deve ser um problema derivado da chamada do GeoPandas para um método na pyproj]

# %%
fmap = folium.Map(location=[-23.5, -46.6], zoom_start=10)

file_path = 'treated_data/sao_paulo_demographics.geojson'

polygons1 = gpd.read_file(file_path)

polygons1.crs = {'init': 'epsg:31983'}
polygons1.to_crs(epsg='4326', inplace=True)

folium.Choropleth(
    geo_data=polygons1,
    name='choropleth',
    data=polygons1,
    columns=['id', 'populacao'],
    key_on='feature.properties.id',
    fill_color='OrRd',
    fill_opacity=0.9,
    line_opacity=0.1,
    legend_name='Densidade Populacional (hab/ha)'
).add_to(fmap)
# Out:
# C:\Users\jojos\.conda\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %% [markdown]
# Parte 3.1: Carregamento dos pontos de interesse e determinação do raio de distância máximo dos pontos

# %%
radius = 1000

# trecho realocado da parte 3.3 para 3.1, para fins de clareza-------------
POI_file_path = "treated_data/interest_points.geojson"
polygons2 = gpd.read_file(POI_file_path)
#--------------------------------------------------------------------------

def handle_slider_change_with_delay(change):
    def compute_new_radius():
        global radius
        radius = change.new
        print("New radius value:", radius)
    widgets.interact_manual(compute_new_radius)
    sleep(2)

slider = widgets.IntSlider(value=1000, min=1000, max=5000, step=250, description='Raio')
slider.observe(handle_slider_change_with_delay, names='value')

display(slider)
# Out:
# IntSlider(value=1000, description='Raio', max=5000, min=1000, step=250)

# %% [markdown]
# Parte 3.2: Visualização do raio

# %%
folium.Circle(
    location=[-23.526073932488359, -46.668179848334979],
    radius=radius,
    color='blue',
    fill=True,
    fill_color='blue',
    fill_opacity=0.3,
).add_to(gmap)

folium.Marker(
    location=[-23.526073932488359, -46.668179848334979],
).add_to(gmap)

gmap

# %% [markdown]
# Parte 3.3: Plotting dos pontos de interesse (o trecho comentado
#                                                             plota o mapa, é um guia visual.)

# %%
circle_group = folium.FeatureGroup(name='Circles')
for idx, point in polygons2.iterrows():
    folium.Circle(
        location=[point['geometry'].x, point['geometry'].y],
        radius=radius,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.3,
    ).add_to(circle_group)
marker_group = folium.FeatureGroup(name='Markers')
for idx, point in polygons2.iterrows():
    folium.Marker(
        location=[point['geometry'].x, point['geometry'].y],
    ).add_to(marker_group)
    
circle_group.add_to(fmap)
marker_group.add_to(fmap)
# folium.LayerControl().add_to(fmap)
# display(polygons2)

# %% [markdown]
# Parte 4: Criação das zonas de buffer (sistema de cordenadas resolvido)

# %%
dist_point_gdf = polygons2['geometry'][0]
transformer1 = pyproj.Transformer.from_crs('epsg:4326', 'epsg:32634', always_xy=True)
transformer2 = pyproj.Transformer.from_crs('epsg:32634', 'epsg:4326', always_xy=True)
new_x, new_y = transformer1.transform(dist_point_gdf.x, dist_point_gdf.y)
newer_x = new_x+radius
pbase_4326 = Point(transformer2.transform(new_x, new_y))
pdistance_4326 = Point(transformer2.transform(newer_x, new_y))
radius2 = pbase_4326.distance(pdistance_4326)

# trecho realocado a essa célula, estava separado durante o desenvolvimento-------
polygons2_buffer = gpd.GeoDataFrame(geometry=[], crs="EPSG:4326")

for index, row in polygons2.iterrows():
    coords = Point(row['geometry'].y, row['geometry'].x)
    buffer_geometry = coords.buffer(radius2)
    polygons2_buffer = pd.concat([polygons2_buffer, gpd.GeoDataFrame(geometry=[buffer_geometry], crs="EPSG:4326")], ignore_index=True)

# display(polygons2_buffer)
# para facilitar os testes--------------------------------------------------------

# %% [markdown]
# Parte 5: Ponte com o sorter

# %% [markdown]
# Organização 1:1 (defina um atributo chave, a função ordena segundo tal atributo)

# %%
key_factor = 'populacao'

result11_gdf = sort.sorter11(polygons1, polygons2_buffer, key_factor)

display(result11_gdf)

# %% [markdown]
# Organização 1:N (defina um atributo chave e um tamanho, a célula ordena segundo tal atributo
#                  e retorna um dataframe com o número especificado de linhas [por padrão,
#                  o dataframe inteiro é iterado])

# %%
key_factor = 'habit_hect'
size = 200

polygons1 = polygons1.sort_values(by=key_factor, ascending=False)
polygons1 = polygons1.dropna()
polygons1 = polygons1.reset_index(drop=True)
polygons1 = polygons1[:size]

result1_gdf, result2_gdf = sort.sorter1n(polygons1, polygons2_buffer)

result1n_gdf = gpd.GeoDataFrame(geometry=[])
result1n_gdf['polygon1_center'] = result1_gdf['geometry']
result1n_gdf['polygon2_center'] = result2_gdf['geometry']
display(result1n_gdf)

# %% [markdown]
# Parte 6: Pather

# %%
def graphopper_request(url, row):
    p_latitude = row['polygon1_center'].y
    p_longitude = row['polygon1_center'].x
    c_latitude = row['polygon2_center'].y
    c_longitude = row['polygon2_center'].x
    response = requests.get(url.format(p_latitude, p_longitude, c_latitude, c_longitude))
    if response.status_code == 200:
        json_data = response.json()
        return json_data
    else:
        raise Exception(f"Error: {response.status_code}")

def convert_list_columns_to_str(df):
    for col in df.columns:
        if df[col].apply(type).eq(list).any():
            df[col] = df[col].astype(str)
    return df
        
def graphhopper_pather(POI_gdf, json_filename, limit):
    
    graph_hopper_key = '9463c059-8653-4efd-be7e-548ef8f697b8'

    url = 'https://graphhopper.com/api/1/route?key=' + graph_hopper_key + \
    '&point={},{}&point={},{}&vehicle=bike&elevation=true&type=json&points_encoded=false'

    gdf = gpd.GeoDataFrame(geometry=[])

    for count, (index, row) in enumerate(POI_gdf.iterrows()):
        sleep(1)
        if (count>limit):
            break
        data_from_request = graphopper_request(url, row)
        gdf = gdf.append(data_from_request, ignore_index=True)
    paths = gdf['paths'].to_json()
    gdf = convert_list_columns_to_str(gdf)
    display(gdf)
    gdf.to_file(json_filename, driver='GeoJSON')
    return gdf

# %% [markdown]
# Parte 6.1: Defina um limite para o pather, por padrão ele itera todo o geodataframe na ordem definida.
#
# Defina também qual dataframe será usado, atendo-se a um por vez.

# %%
file_name = "treated_data/caminhos_bike_1000m_11.geojson"
limit = 200
#data = graphhopper_pather(result1n_gdf, file_name, limit)
data = graphhopper_pather(result11_gdf, file_name, limit)

# %% [markdown]
# (Opção alternativa: carregar caminhos pré-calculados)

# %%
file_name = "requests/caminhos_bike_5000m_11.geojson"
with open(file_name, 'r', encoding='utf-8') as file:
    data = json.load(file)

# %% [markdown]
# Parte 7: Mapper - Plota o mapa com os caminhos e salva como html

# %%
html_name = file_name.split(".", 1)[0] + ".html"
i = 0
coordinates_gdf = gpd.GeoDataFrame(geometry=[])

while i < len(data['features']):
    coordinates = data['features'][i]['properties']['paths'][0]['points']['coordinates']
    linestring_coordinates = LineString([(point[0], point[1]) for point in coordinates])
    temp_gdf = gpd.GeoDataFrame(geometry=[linestring_coordinates])
    coordinates_gdf = pd.concat([coordinates_gdf, temp_gdf], ignore_index=True)

    # Create the GeoJson object with a style function to set the color to red
    folium.GeoJson(
        data={
            'type': 'Feature',
            'geometry': linestring_coordinates.__geo_interface__
        },
        name='LineString',
        style_function=lambda x: {'color': 'red'}
    ).add_to(fmap)
    i += 1

folium.LayerControl().add_to(fmap)
fmap.save(html_name)

# %%
hmap = folium.Map(location=[-23.5, -46.6], zoom_start=10)

# %%
# cria o mapa apenas com as rotas

html_name = file_name.split(".", 1)[0] + ".html"
i = 0
coordinates_gdf = gpd.GeoDataFrame(geometry=[])

while i < len(data['features']):
    coordinates = data['features'][i]['properties']['paths'][0]['points']['coordinates']
    linestring_coordinates = LineString([(point[0], point[1]) for point in coordinates])
    temp_gdf = gpd.GeoDataFrame(geometry=[linestring_coordinates])
    coordinates_gdf = pd.concat([coordinates_gdf, temp_gdf], ignore_index=True)

    # Create the GeoJson object with a style function to set the color to red
    folium.GeoJson(
        data={
            'type': 'Feature',
            'geometry': linestring_coordinates.__geo_interface__
        },
        name='LineString',
        style_function=lambda x: {'color': 'red'}

    i += 1

hmap.save(html_name)
