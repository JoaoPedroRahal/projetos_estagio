# %%
#Coffee Production of 2021 (in millions of 60kg bags)

# %%
import pandas as pd
import geopandas as gpd

#world_data = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

#world_df = pd.DataFrame(world_data)

brazil_data = gpd.read_file('bcim_2016_21_11_2018.gpkg', layer = 'lim_unidade_federacao_a')

brazil_df = pd.DataFrame(brazil_data)

coffee_data = {'State': ['Acre', 'Alagoas', 'Amapá', 'Amazonas', 'Bahia', 'Ceará', 'Espírito Santo', 'Goiás', 'Maranhão', 'Mato Grosso', 'Mato Grosso do Sul', 'Minas Gerais', 'Pará', 'Paraíba', 'Paraná', 'Pernambuco', 'Piauí', 'Rio de Janeiro', 'Rio Grande do Norte', 'Rio Grande do Sul', 'Rondônia', 'Roraima', 'Santa Catarina', 'São Paulo', 'Sergipe', 'Tocantins'],
        'Coffee_Production': [0.095, 0.23, 0.045, 0.5, 4.1, 0.16, 14.8, 1.7, 1.2, 1.6, 0.085, 26.5, 0.75, 0.14, 1.8, 0.13, 0.83, 0.788, 0.145, 0.38, 2.3, 0.02, 0.35, 6.3, 0.175, 0.847]}

coffee_df = pd.DataFrame(coffee_data)

brazil_df = brazil_df.rename(columns={'nome':'State'})

coffee_brazil_df = pd.merge(coffee_df, brazil_df, on='State', how='inner')

#display(coffee_df)
#brazil.columns
#display(brazil_df)
#display(coffee_brazil_df)
#display(world_df)

# %%
no_use_or_repeated = ['nomeabrev', 'geocodigo', 'geometriaaproximada', 'id_produtor', 'id_elementoprodutor', 'cd_insumo_orgao', 'nr_insumo_mes', 'nr_insumo_ano', 'tx_insumo_documento']

if all(col in coffee_brazil_df for col in no_use_or_repeated):
        coffee_brazil_df.drop(no_use_or_repeated, axis=1, inplace=True)

#display(coffee_brazil_df)

#coffee_brazil_world_df = world_df.merge(coffee_brazil_df, how='left', left_on='geometry', right_on='nome')

#coffee_brazil_world_df = pd.merge(coffee_brazil_df, world_df, on)

#display(coffee_brazil_world_df)

# %%
from unidecode import unidecode

brazil_df['State'] = brazil_df['State'].apply(lambda x: unidecode(x))

coffee_brazil_df['State'] = coffee_brazil_df['State'].apply(lambda x: unidecode(x))

display(coffee_brazil_df)
# Out:
#                   State  Coffee_Production sigla  \
# 0                  Acre              0.095    AC
# 1               Alagoas              0.230    AL
# 2                 Amapa              0.045    AP
# 3              Amazonas              0.500    AM
# 4                 Bahia              4.100    BA
# 5                 Ceara              0.160    CE
# 6        Espirito Santo             14.800    ES
# 7                 Goias              1.700    GO
# 8              Maranhao              1.200    MA
# 9           Mato Grosso              1.600    MT
# 10   Mato Grosso do Sul              0.085    MS
# 11         Minas Gerais             26.500    MG
# 12                 Para              0.750    PA
# 13              Paraiba              0.140    PB
# 14               Parana              1.800    PR
# 15           Pernambuco              0.130    PE
# 16                Piaui              0.830    PI
# 17       Rio de Janeiro              0.788    RJ
# 18  Rio Grande do Norte              0.145    RN
# 19    Rio Grande do Sul              0.380    RS
# 20             Rondonia              2.300    RO
# 21              Roraima              0.020    RR
# 22       Santa Catarina              0.350    SC
# 23            Sao Paulo              6.300    SP
# 24              Sergipe              0.175    SE
# 25            Tocantins              0.847    TO
#
#                                              geometry
# 0   MULTIPOLYGON (((-73.73811 -7.13471, -72.90246 ...
# 1   MULTIPOLYGON (((-35.45878 -8.81780, -35.45898 ...
# 2   MULTIPOLYGON (((-51.18178 3.90573, -51.13631 3...
# 3   MULTIPOLYGON (((-67.32285 2.04176, -67.29220 1...
# 4   MULTIPOLYGON (((-38.97119 -8.78270, -38.95972 ...
# 5   MULTIPOLYGON (((-40.42389 -2.81130, -40.41525 ...
# 6   MULTIPOLYGON (((-40.47978 -17.91795, -40.46958...
# 7   MULTIPOLYGON (((-50.15876 -12.41581, -50.15743...
# 8   MULTIPOLYGON (((-42.03760 -2.70322, -42.04097 ...
# 9   MULTIPOLYGON (((-60.10041 -12.91271, -60.09773...
# 10  MULTIPOLYGON (((-56.09815 -17.17220, -56.09159...
# 11  MULTIPOLYGON (((-44.21152 -14.22955, -44.20750...
# 12  MULTIPOLYGON (((-46.25020 -1.13999, -46.25285 ...
# 13  MULTIPOLYGON (((-37.21443 -6.03725, -37.20704 ...
# 14  MULTIPOLYGON (((-52.08090 -22.52893, -52.04903...
# 15  MULTIPOLYGON (((-32.38846 -3.81629, -32.39054 ...
# 16  MULTIPOLYGON (((-41.73344 -2.81111, -41.73205 ...
# 17  MULTIPOLYGON (((-41.70343 -22.42014, -41.70380...
# 18  MULTIPOLYGON (((-35.20267 -5.74677, -35.20324 ...
# 19  MULTIPOLYGON (((-53.03425 -27.15455, -53.03079...
# 20  MULTIPOLYGON (((-62.79892 -8.02312, -62.78622 ...
# 21  MULTIPOLYGON (((-60.17793 5.23024, -60.16619 5...
# 22  MULTIPOLYGON (((-48.63761 -25.97490, -48.63504...
# 23  MULTIPOLYGON (((-45.01051 -23.76176, -45.01624...
# 24  MULTIPOLYGON (((-38.00366 -9.51544, -38.00052 ...
# 25  MULTIPOLYGON (((-48.34644 -5.17871, -48.34311 ...

# %%
# Convert the DataFrame to a GeoDataFrame
gdf = gpd.GeoDataFrame(coffee_brazil_df)

# Save the GeoDataFrame as a GeoJSON file
geojson_path = 'coffee_brazil.geojson'
gdf.to_file(geojson_path, driver='GeoJSON')
# Out:
# C:\Users\jojos\.conda\envs\geo_env\Lib\site-packages\geopandas\io\file.py:299: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %% [markdown]
# txtest = brazil_df.to_string()
#
# file_path = 'braziltest.txt'
#
# with open(file_path, 'w') as file:
#     file.write(txtest)

# %% [markdown]
# from shapely.geometry import shape
#
# #print(coffee_brazil_df.dtypes)
# #print(coffee_brazil_df['geometry'].isnull().sum())
# for geometry in coffee_brazil_df['geometry']:
#     if not geometry.is_valid:
#         print(f"Invalid geometry: {geometry}")

# %%
import folium

map = folium.Map(location=[-15, -50], zoom_start=3.5 )

geojson_path = 'coffee_brazil.geojson'

folium.Choropleth(
    geo_data=geojson_path,
    name='choropleth',
    data=coffee_brazil_df,
    columns=['State', 'Coffee_Production'],
    key_on='feature.properties.State',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Coffee Production'
).add_to(map)

folium.LayerControl().add_to(map)

map.save('coffee_brazil_map.html')

# %%
#import pandas as pd
#import geopandas as gpd
#from unidecode import unidecode
#import json

with open('br.json', encoding='utf-8') as file:
    city_data = json.load(file)
    
for city_info in city_data:
    city = city_info['city']
    lat = float(city_info['lat'])
    lon = float(city_info['lng'])
    
    marker = folium.Marker(location=[lat, lon], popup=city)
    marker.add_to(map)
    
map.save('coffee_brazil_map.html')

# %%
#import folium
#import pandas as pd
#import geopandas as gpd
#import json
#from unidecode import unidecode

with open('br.json', encoding = 'utf-8') as file:
    city_data = json.load(file)

city_df = pd.DataFrame(city_data)
city_df['city'] = city_df['city'].apply(lambda x: unidecode(x))

#display(city_df)

for i in range(len(city_df)):
    city_A = city_df.loc[i, 'city']
    city_B = city_df.loc[(i + 1) % len(city_df), 'city']
    #print(city_B)
    coor_A = (float(city_df.loc[i, 'lat']), float(city_df.loc[i, 'lng']))
    coor_B = (float(city_df.loc[(i + 1) % len(city_df), 'lat']), float(city_df.loc[(i + 1) % len(city_df), 'lng']))
    #print(coor_A)
    line = folium.PolyLine([coor_A, coor_B], color='blue')
    line.add_to(map)
    
map.save('coffee_brazil_map.html')
